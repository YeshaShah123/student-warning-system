# %% [markdown]
# # 02 SQL Analytics
# Run the five SQL analytics functions against the SQLite database.

# %%
import os
import sys
sys.path.append('../src')
from sqlalchemy import create_engine
from database import (
    q1_pass_rate_by_studytime, q2_high_risk_students,
    q3_grade_by_parent_edu, q4_absence_impact, q5_student_ranking
)

engine = create_engine('sqlite:///../data/students.db')

# %%
q1_pass_rate_by_studytime(engine)

# %%
q2_high_risk_students(engine)

# %%
q3_grade_by_parent_edu(engine)

# %%
q4_absence_impact(engine)

# %%
q5_student_ranking(engine)
